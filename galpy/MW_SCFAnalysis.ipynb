# %%
import SCFAnalysis.Plot as plot
from SCFAnalysis.Constants import *
import numpy as nu

import matplotlib.pyplot as plt
from IPython.display import display, Math, Latex
# %matplotlib inline

# %%
folder = "SCFOriginal"
loc = "SCFAnalysis/Orbits/{0}".format(folder)

# %%
Acos = nu.load(loc + "/Acos.npy")
plot.plotAxiCoeffs(Acos, .2)

# %%
plot.plotRA_DEC(loc, 0.001,1*units.Myr)

# %%
plot.plotRA_DEC(loc, 0.002,1*units.Myr)

# %%
plot.plotRA_DEC(loc, 0.004,1*units.Myr)

# %%
plot.plotRA_DEC(loc, 0.008,1*units.Myr, fit=False)

# %%
plot.plotRA_DEC(loc, 0.01,1*units.Myr, fit=False)

# %% [markdown]
# ## Adjusting Acos

# %%
plot.plotAxiCoeffsVarying_n(Acos, log=True)

# %%
plot.plotAxiCoeffsVarying_n(Acos, n_start=1, n_end=2)
plt.plot(1,-.66, "o")

# %%
folder = "SCF_n=1_l=1_Acos=-.66"
loc = "SCFAnalysis/Orbits/{0}".format(folder)

# %%
Acos = nu.load(loc + "/Acos.npy")
plot.plotAxiCoeffs(Acos, .2)

# %%
plot.plotRA_DEC(loc, 0.001,1*units.Myr)

# %%
plot.plotRA_DEC(loc, 0.002,1*units.Myr)

# %%
plot.plotRA_DEC(loc, 0.004,1*units.Myr)

# %%
plot.plotRA_DEC(loc, 0.008,1*units.Myr, False)
