# %%
import SCFAnalysis.Plot as plot
from SCFAnalysis.Constants import *
from SCFAnalysis.func import *
import numpy as nu
from galpy.potential import SCFPotential, plotDensities, plotPotentials

import matplotlib.pyplot as plt
from IPython.display import display, Math, Latex
# %matplotlib inline
# Out:
# ...
# /usr/lib64/python2.7/site-packages/matplotlib/__init__.py:1320: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
folder = "SCFOriginal"
loc = "SCFAnalysis/Orbits/{0}".format(folder)

# %%
Acos = nu.load(loc + "/Acos.npy")
plot.plotAxiCoeffs(Acos, .2)

# %%
scf = SCFPotential(Acos=Acos, a=200./8,normalize=.35)
plotDensities(scf)
plotPotentials(scf)

# %%
plot.plotRA_DEC(loc, 0.001,1*units.Myr)

# %%
plot.plotRA_DEC(loc, 0.002,1*units.Myr)

# %%
plot.plotRA_DEC(loc, 0.004,1*units.Myr)

# %%
plot.plotRA_DEC(loc, 0.008,1*units.Myr, fit=False)

# %%
plot.plotRA_DEC(loc, 0.01,1*units.Myr, fit=False)

# %% [markdown]
# ## Adjusting Acos

# %%
plot.plotAxiCoeffsVarying_n(Acos, log=False)

# %%
plot.plotAxiCoeffsVarying_n(Acos, n_start=1, n_end=2)
plt.plot(1,-.66, "o")

# %%
folder = "SCF_n=1_l=1_Acos=-.66"
loc = "SCFAnalysis/Orbits/{0}".format(folder)

# %%
Acos = nu.load(loc + "/Acos.npy")
plot.plotAxiCoeffs(Acos, .2)

# %%
scf = SCFPotential(Acos=Acos, a=200./8)
plotDensities(scf)
plotPotentials(scf)

# %%
plot.plotRA_DEC(loc, 0.001,1*units.Myr)

# %%
plot.plotRA_DEC(loc, 0.002,1*units.Myr)

# %%
plot.plotRA_DEC(loc, 0.004,1*units.Myr)

# %%
plot.plotRA_DEC(loc, 0.008,1*units.Myr, False)

# %%
plot.plotAxiCoeffsVarying_n(Acos, n_start=1, n_end=4)
plt.plot(1,-.66, "o")
plt.plot(1, .317, "o")
plt.plot(1, -0.086877150608839715, "o")

# %%
a = (-(Acos[1,0,0] + 4*Acos[1,2,0])/.66)**-1

# %%
n=nu.arange(1, 30)
l1_vals = a*(Acos[n,0,0] + 4*Acos[n,2,0])

# %%
Acos[1:,1,0] = l1_vals
##nu.save("SCFAnalysis/Orbits/SCF_Acos2/Acos.npy", Acos)

# %%
folder = "SCF_Acos2"
loc = "SCFAnalysis/Orbits/{0}".format(folder)

# %%
Acos = nu.load(loc + "/Acos.npy")
plot.plotAxiCoeffs(Acos, .2)

# %%
scf = SCFPotential(Acos=Acos, a=200./8)
plotDensities(scf)
plotPotentials(scf)

# %%
plot.plotRA_DEC(loc, 0.004,1*units.Myr, alpha=1.)

# %%
n=nu.arange(0, 30)
l1_vals = a*(Acos[n,0,0] + 4*Acos[n,2,0])
Acos[:,1,0] = l1_vals
#nu.save("SCFAnalysis/Orbits/SCF_Acos3/Acos.npy", Acos)

# %%
folder = "SCF_Acos3"
loc = "SCFAnalysis/Orbits/{0}".format(folder)

# %%
Acos = nu.load(loc + "/Acos.npy")
plot.plotAxiCoeffs(Acos, .2)

# %%
scf = SCFPotential(Acos=Acos, a=200./8)
plotDensities(scf)
plotPotentials(scf)

# %%
plot.plotRA_DEC(loc, 0.004,1*units.Myr)

# %%
folder = nu.array(["SCFOriginal","SCF_n=1_l=1_Acos=-.66","SCF_Acos3"])
plot.plotFitFromFolders(folder)

# %%
folder = "SCF_Acos_N30_L30"
loc = "SCFAnalysis/Orbits/{0}".format(folder)

Acos = nu.load(loc + "/Acos.npy")

# %%
plot.plotAxiCoeffs(Acos, .2)

# %%
plot.plotRA_DEC(loc, 0.004,1*units.Myr)

# %%
plot.plotAxiCoeffsVarying_n(Acos, n_start=2, n_end=3, l_step=2)

# %%
x = Acos[1,:,0].copy()
y = (x[:-2:2] + x[2::2])/2
x[1:-1:2] = y
Acos[1,1:-1:2,0] = y
plt.plot(x[::1])

# %%
plot.plotAxiCoeffs(Acos, .2)
##nu.save("SCFAnalysis/Orbits/SCF_Acos2_N30_L30/Acos.npy", Acos)

# %%
folder = "SCF_Acos2_N30_L30"
loc = "SCFAnalysis/Orbits/{0}".format(folder)

# %%
scf = SCFPotential(Acos=Acos, a=200./8)
plotDensities(scf)
plotPotentials(scf)

# %%
plot.plotRA_DEC(loc, 0.004,1*units.Myr)

# %%
folder = "SCF_Acos_N30_L30"
loc = "SCFAnalysis/Orbits/{0}".format(folder)

Acos = nu.load(loc + "/Acos.npy")
x = Acos[1:,:,0].copy()
y = (x[:, :-2:2] + x[:, 2::2])/2
x[:, 1:-1:2] = y
Acos[1:,1:-1:2,0] = y
plot.plotAxiCoeffs(Acos, .2)
##nu.save("SCFAnalysis/Orbits/SCF_Acos3_N30_L30/Acos.npy", Acos)

# %%
scf = SCFPotential(Acos=Acos, a=200./8)
plotDensities(scf)
plotPotentials(scf)

# %%
folder = "SCF_Acos3_N30_L30"
loc = "SCFAnalysis/Orbits/{0}".format(folder)

# %%
plot.plotRA_DEC(loc, 0.004,1*units.Myr)

# %%
folder = "SCF_Acos_N30_L30"
loc = "SCFAnalysis/Orbits/{0}".format(folder)

Acos = nu.load(loc + "/Acos.npy")
x = Acos[:,:,0].copy()
y = (x[:, :-2:2] + x[:, 2::2])/2
x[:, 1:-1:2] = y
Acos[:,1:-1:2,0] = y
plot.plotAxiCoeffs(Acos, .2)
##nu.save("SCFAnalysis/Orbits/SCF_AcosFull_N30_L30/Acos.npy", Acos)

# %%
scf = SCFPotential(Acos=Acos, a=200./8)
plotDensities(scf)
plotPotentials(scf)

# %%
folder = "SCF_AcosFull_N30_L30"
loc = "SCFAnalysis/Orbits/{0}".format(folder)
plot.plotRA_DEC(loc, 0.004,1*units.Myr, split=False)

# %%
folder = nu.array(["SCF_Acos_N30_L30","SCF_Acos2_N30_L30","SCF_Acos3_N30_L30", "SCF_AcosFull_N30_L30"])
plot.plotFitFromFolders(folder, split=True, ra_bounds=[215,240])

# %%
l = nu.arange(0,30, dtype=float)
r = 100
phi = (r)**(-l - 4)## Set a =1, r >> a

# %%
potential.MWPotential2014
